# %%
import pandas as pd
import numpy as np

# %%
# Read the file
df = pd.read_csv('Datasets/airquality.csv')

# %%
# The number of rows and columns
df.shape
# Out:
# (153, 7)

# %%
#The name of columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day'], dtype='object')

# %%
# To print Rows from 10 to 25 
x = df.iloc[10:26,:]   
x
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 10          11    7.0      NaN   6.9    74      5   11
# 11          12   16.0    256.0   9.7    69      5   12
# 12          13   11.0    290.0   9.2    66      5   13
# 13          14   14.0    274.0  10.9    68      5   14
# 14          15   18.0     65.0  13.2    58      5   15
# 15          16   14.0    334.0  11.5    64      5   16
# 16          17   34.0    307.0  12.0    66      5   17
# 17          18    6.0     78.0  18.4    57      5   18
# 18          19   30.0    322.0  11.5    68      5   19
# 19          20   11.0     44.0   9.7    62      5   20
# 20          21    1.0      8.0   9.7    59      5   21
# 21          22   11.0    320.0  16.6    73      5   22
# 22          23    4.0     25.0   9.7    61      5   23
# 23          24   32.0     92.0  12.0    61      5   24
# 24          25    NaN     66.0  16.6    57      5   25
# 25          26    NaN    266.0  14.9    58      5   26

# %%
# Sorted value on Temperature
df.sort_values('Temp')
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 4             5    NaN      NaN  14.3    56      5    5
# 17           18    6.0     78.0  18.4    57      5   18
# 24           25    NaN     66.0  16.6    57      5   25
# 26           27    NaN      NaN   8.0    57      5   27
# 14           15   18.0     65.0  13.2    58      5   15
# ..          ...    ...      ...   ...   ...    ...  ...
# 41           42    NaN    259.0  10.9    93      6   11
# 122         123   85.0    188.0   6.3    94      8   31
# 120         121  118.0    225.0   2.3    94      8   29
# 121         122   84.0    237.0   6.3    96      8   30
# 119         120   76.0    203.0   9.7    97      8   28
#
# [153 rows x 7 columns]

# %%
# To convert Temperature from Farenheit to celsius
df['Temp'] =  df['Temp'] -32*5/9

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind       Temp  Month  Day
# 0             1   41.0    190.0   7.4  49.222222      5    1
# 1             2   36.0    118.0   8.0  54.222222      5    2
# 2             3   12.0    149.0  12.6  56.222222      5    3
# 3             4   18.0    313.0  11.5  44.222222      5    4
# 4             5    NaN      NaN  14.3  38.222222      5    5
# ..          ...    ...      ...   ...        ...    ...  ...
# 148         149   30.0    193.0   6.9  52.222222      9   26
# 149         150    NaN    145.0  13.2  59.222222      9   27
# 150         151   14.0    191.0  14.3  57.222222      9   28
# 151         152   18.0    131.0   8.0  58.222222      9   29
# 152         153   20.0    223.0  11.5  50.222222      9   30
#
# [153 rows x 7 columns]

# %%
# information of 5th month
x = df[(df['Month']==5)]

# %%
x
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind       Temp  Month  Day
# 0             1   41.0    190.0   7.4  49.222222      5    1
# 1             2   36.0    118.0   8.0  54.222222      5    2
# 2             3   12.0    149.0  12.6  56.222222      5    3
# 3             4   18.0    313.0  11.5  44.222222      5    4
# 4             5    NaN      NaN  14.3  38.222222      5    5
# ..          ...    ...      ...   ...        ...    ...  ...
# 148         149   30.0    193.0   6.9  52.222222      5   26
# 149         150    NaN    145.0  13.2  59.222222      5   27
# 150         151   14.0    191.0  14.3  57.222222      5   28
# 151         152   18.0    131.0   8.0  58.222222      5   29
# 152         153   20.0    223.0  11.5  50.222222      5   30
#
# [153 rows x 7 columns]

# %%
df1 = pd.read_csv('Datasets/cricket.csv')

# %%
df1
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings
# 0      1    Anil Dalpat      122  6755       56       12          0
# 1      2   Rohan Kanhay      144  1256       76      178          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 3      4       Bahubali       10   756        6       11          3
# 4      5      Leeladhar      234  2866      105      376          0
# 5      6      Pradyumna      177  5877       47      122          0
# 6      7     Dinesh Roy      211  8537      112       16          0
# 7      8     Parmeshwar      245  9466       53        0          0
# 8      9    Ali Durrani       55  2756       12       26          0
# 9     10   Litesh Singh       89  1099       46       49          0

# %%
df1.loc[:,['name','runs']] #All rows with label name and runs
# Out:
#             name  runs
# 0    Anil Dalpat  6755
# 1   Rohan Kanhay  1256
# 2  Avdhoot Dighe  8954
# 3       Bahubali   756
# 4      Leeladhar  2866
# 5      Pradyumna  5877
# 6     Dinesh Roy  8537
# 7     Parmeshwar  9466
# 8    Ali Durrani  2756
# 9   Litesh Singh  1099

# %%
# total wickets
df1['wickets'].sum()
# Out:
# 790

# %%
# Average catches
df1['catches'].sum()/df1['catches'].count()
# Out:
# 63.3

# %%
# Strike rate of all batsmen

# Formula is not given

# %%
# Strike rate greater than 50

# %%
# Name of Wicketkeeper

# %%
#name of bowler who played heighest number of matches

df1['matches'].max()
# Out:
# 265

# %%
x = df1[(df1['matches'] == df1['matches'].max())]

# %%
x.name
# Out:
# 2    Avdhoot Dighe
# Name: name, dtype: object

# %%
# Average of all bowlers
#Bowler details not given

# %%
#bowling Average
# Details not given

# %%
#details of all players whose catches per match ratio is greater than 0.5
x = df1[(df1['catches']/ df1['matches'] )>0.5]

# %%
x
# Out:
#    sr.no          name  matches  runs  catches  wickets  stumpings
# 1      2  Rohan Kanhay      144  1256       76      178          0
# 3      4      Bahubali       10   756        6       11          3
# 6      7    Dinesh Roy      211  8537      112       16          0
# 9     10  Litesh Singh       89  1099       46       49          0

# %%
x.to_csv('Datasets/players.csv',index=False)

# %%
#Name of players whose wickets are greater than matches
x = df1[(df1['wickets'] >df1['matches'] )]

# %%
x
# Out:
#    sr.no          name  matches  runs  catches  wickets  stumpings
# 1      2  Rohan Kanhay      144  1256       76      178          0
# 3      4      Bahubali       10   756        6       11          3
# 4      5     Leeladhar      234  2866      105      376          0

# %%
x.name
# Out:
# 1    Rohan Kanhay
# 3        Bahubali
# 4       Leeladhar
# Name: name, dtype: object

# %%
#plot the chart
import matplotlib.pyplot as plt
plt.title('Matches Vs Runs')
plt.xlabel('Matches')
plt.ylabel('Runs')
plt.grid()
plt.plot(df1['matches'],df1['runs'], color='green')

# %%
df1.sort_values('runs')
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings
# 3      4       Bahubali       10   756        6       11          3
# 9     10   Litesh Singh       89  1099       46       49          0
# 1      2   Rohan Kanhay      144  1256       76      178          0
# 8      9    Ali Durrani       55  2756       12       26          0
# 4      5      Leeladhar      234  2866      105      376          0
# 5      6      Pradyumna      177  5877       47      122          0
# 0      1    Anil Dalpat      122  6755       56       12          0
# 6      7     Dinesh Roy      211  8537      112       16          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 7      8     Parmeshwar      245  9466       53        0          0
