# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#Load the image
img = cv2.imread('images/lenna.png',0)

# %%
#sobel parameters:ksize, dx, dy, ddepth
#Sobel for horizontal edge
sobelx = cv2.Sobel(img, cv2.CV_64F,1,0, ksize=3)
#Sobel for horizontal edge
sobely = cv2.Sobel(img, cv2.CV_64F,0,1, ksize=3)

#Combine the Sobel images (optional)
combined_sobel = cv2.add(sobelx ,sobely)

# %%
final_img = np.hstack([sobelx,sobely,combined_sobel])
cv2.imshow('All Images',final_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.figure(figsize=(16,8))
plt.subplot(141)
plt.title('Original Image')
plt.imshow(img, cmap='gray')
plt.subplot(142)
plt.title('Sobel X Image')
plt.imshow(abs(sobelx), cmap='gray')
plt.subplot(143)
plt.title('Sobel Y  Image')
plt.imshow(abs(sobely), cmap='gray')
plt.subplot(144)
plt.title('Combined Image')
plt.imshow(abs(combined_sobel), cmap='gray')

# %%
##### Canny Edge Detection

# %%
# load the image
img = cv2.imread('images/lenna.png',0) 

#Apply Canny edge detection
edges = cv2.Canny(img, 50,150) # Adjust thresholds if needed

# Disply Results
cv2.imshow('Original Image', img)
cv2.imshow('Canny Edge Detection', edges)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# load the image
img = cv2.imread('images/circle.png',0) 

#Apply Canny edge detection
edges = cv2.Canny(img, 50,150) # Adjust thresholds if needed

# Disply Results
cv2.imshow('Original Image', img)
cv2.imshow('Canny Edge Detection', edges)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# load the image
img = cv2.imread('images/houseleft.jpg',0) 

#Apply Canny edge detection
edges = cv2.Canny(img, 50,75) # Adjust thresholds if needed

# Disply Results
cv2.imshow('Original Image', img)
cv2.imshow('Canny Edge Detection', edges)
cv2.waitKey()
cv2.destroyAllWindows()
