# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0,50,0.05)

# %%
y  = np.sin(x)
z = np.cos(x)

# %%
plt.figure(figsize=(10,9))
plt.plot(x,y)
plt.plot(x,z)

# %%
import cv2
# load the image
image =  cv2.imread('images/lenna.png')

# Rotate the image 45 degrees clockwise
rotated_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)

#show the rotated image
cv2.imshow("Rotated Image",rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\rajesh'

# %%
# load the image
image =  cv2.imread('images/lenna.png')

# Rotate the image 45 degrees clockwise
rotated_image = cv2.rotate(image, cv2.ROTATE_180)

#show the rotated image
cv2.imshow("Rotated Image",rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# load the image
image =  cv2.imread('images/lenna.png')

# Rotate the image 45 degrees clockwise
rotated_image = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE)

#show the rotated image
cv2.imshow("Rotated Image",rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
##### Rotation using matrix

# %%
# load the image
image =  cv2.imread('images/lenna.png')

#Define the center point and rotation angle
center = (image.shape[1]//2, image.shape[0]//2)
angle = -60
#Create the rotation matrix
rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)

#Apply the rotation using warpAffine
rotated_image = cv2.warpAffine(image, rotation_matrix,(image.shape[1],image.shape[0]))
#show the rotated image
cv2.imshow("Rotated Image",rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
rotation_matrix
# Out:
# array([[  0.5       ,  -0.8660254 , 349.70250337],
#        [  0.8660254 ,   0.5       , -93.70250337]])

# %%
# load the image
image =  cv2.imread('images/lenna.png')

#Define the center point and rotation angle
center = (image.shape[1]//2, image.shape[0]//2)
angle = -60
#Create the rotation matrix
rotation_matrix = cv2.getRotationMatrix2D((100,100), angle, 1.0)

#Apply the rotation using warpAffine
rotated_image = cv2.warpAffine(image, rotation_matrix,(image.shape[1],image.shape[0]))
#show the rotated image
cv2.imshow("Rotated Image",rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
##### Rotation using PIL

# %%
from PIL import Image
image = Image.open('images/lenna.png')

# %%
converted_img = image.transpose(Image.ROTATE_180)
converted_img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
converted_img = image.transpose(Image.ROTATE_90)
converted_img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
converted_img = image.transpose(Image.ROTATE_270)
converted_img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
