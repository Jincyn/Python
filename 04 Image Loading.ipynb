8 MB 11.7 MB/s eta 0:00:02
#    ------------------------ --------------- 23.5/38.8 MB 11.7 MB/s eta 0:00:02
#    ------------------------ --------------- 24.1/38.8 MB 11.7 MB/s eta 0:00:02
#    ------------------------- -------------- 24.6/38.8 MB 11.7 MB/s eta 0:00:02
#    ------------------------- -------------- 25.2/38.8 MB 11.7 MB/s eta 0:00:02
#    -------------------------- ------------- 25.7/38.8 MB 11.7 MB/s eta 0:00:02
#    --------------------------- ------------ 26.3/38.8 MB 11.7 MB/s eta 0:00:02
#    --------------------------- ------------ 26.9/38.8 MB 11.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.4/38.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 28.0/38.8 MB 11.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.5/38.8 MB 11.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 29.1/38.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 29.6/38.8 MB 11.7 MB/s eta 0:00:01
#    ------------------------------- -------- 30.2/38.8 MB 11.7 MB/s eta 0:00:01
#    ------------------------------- -------- 30.8/38.8 MB 11.7 MB/s eta 0:00:01
#    -------------------------------- ------- 31.3/38.8 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 31.9/38.8 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 32.5/38.8 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 33.0/38.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.6/38.8 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.1/38.8 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.7/38.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.2/38.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.8/38.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 36.3/38.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 36.9/38.8 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 37.4/38.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 11.1 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.6/2.6 MB 12.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.1/2.6 MB 14.0 MB/s eta 0:00:01
#    ------------------------- -------------- 1.6/2.6 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.2/2.6 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 11.7 MB/s eta 0:00:00
# Downloading scikit_image-0.24.0-cp311-cp311-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB 9.6 MB/s eta 0:00:02
#    - -------------------------------------- 0.4/12.8 MB 6.0 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/12.8 MB 6.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/12.8 MB 7.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.9/12.8 MB 8.4 MB/s eta 0:00:02
#    ------- -------------------------------- 2.4/12.8 MB 9.0 MB/s eta 0:00:02
#    --------- ------------------------------ 3.0/12.8 MB 9.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.5/12.8 MB 9.8 MB/s eta 0:00:01
#    ------------ --------------------------- 4.1/12.8 MB 10.0 MB/s eta 0:00:01
#    -------------- ------------------------- 4.6/12.8 MB 10.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.8 MB 10.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.6/12.8 MB 10.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.6/12.8 MB 10.3 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.8 MB 10.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.4/12.8 MB 10.7 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.8 MB 10.8 MB/s eta 0:00:01
#    -------------------------- ------------- 8.5/12.8 MB 10.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.1/12.8 MB 10.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.6/12.8 MB 11.0 MB/s eta 0:00:01
#    ------------------------------- -------- 10.2/12.8 MB 11.0 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.8 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/12.8 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 12.4/12.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 11.5 MB/s eta 0:00:00
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Installing collected packages: pillow, opencv-python, lazy-loader, scikit-image
# Successfully installed lazy-loader-0.4 opencv-python-4.10.0.84 pillow-10.4.0 scikit-image-0.24.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\rajesh'

# %%
##### Using opencv

# %%
img1 = cv2.imread('images/lenna.png')

# %%
img1
# Out:
# array([[[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        ...,
#
#        [[ 60,  18,  84],
#         [ 60,  18,  84],
#         [ 58,  27,  92],
#         ...,
#         [ 84,  73, 173],
#         [ 76,  68, 172],
#         [ 79,  62, 177]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]]], dtype=uint8)

# %%
cv2.imshow('First Image',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
##### using matplotlib

# %%
import matplotlib.pyplot as plt

# %%
img_plt = plt.imread('images/lenna.png')
plt.imshow(img_plt)

# %%
##### Using Scikit-image

# %%
from skimage import io

# %%
img_ski = io.imread('images/lenna.png')

# %%
io.imshow(img_ski)

# %%
##### using pillow library

# %%
from PIL import Image

# %%
img_pil = Image.open('images/lenna.png')

# %%
img_pil.show()

# %%
img_pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
##### using Tensorflow

# %%
import tensorflow as tf

# %%
img_tf = tf.io.read_file('images/lenna.png')
img_tf = tf.image.decode_image(img_tf,channels=3)

# %%
plt.imshow(img_tf)

# %%
img1
# Out:
# array([[[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        ...,
#
#        [[ 60,  18,  84],
#         [ 60,  18,  84],
#         [ 58,  27,  92],
#         ...,
#         [ 84,  73, 173],
#         [ 76,  68, 172],
#         [ 79,  62, 177]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]]], dtype=uint8)

# %%
img1.shape
# Out:
# (512, 512, 3)

# %%
img_plt.shape
# Out:
# (512, 512, 3)

# %%
img1.dtype, img_plt.dtype
# Out:
# (dtype('uint8'), dtype('float32'))

# %%
img1
# Out:
# array([[[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        ...,
#
#        [[ 60,  18,  84],
#         [ 60,  18,  84],
#         [ 58,  27,  92],
#         ...,
#         [ 84,  73, 173],
#         [ 76,  68, 172],
#         [ 79,  62, 177]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]]], dtype=uint8)

# %%
img_new =

# %%
img_plt
# Out:
# array([[[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        [[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        [[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        ...,
#
#        [[0.32941177, 0.07058824, 0.23529412],
#         [0.32941177, 0.07058824, 0.23529412],
#         [0.36078432, 0.10588235, 0.22745098],
#         ...,
#         [0.6784314 , 0.28627452, 0.32941177],
#         [0.6745098 , 0.26666668, 0.29803923],
#         [0.69411767, 0.24313726, 0.30980393]],
#
#        [[0.32156864, 0.08627451, 0.22352941],
#         [0.32156864, 0.08627451, 0.22352941],
#         [0.3764706 , 0.1254902 , 0.24313726],
#         ...,
#         [0.7019608 , 0.27450982, 0.30980393],
#         [0.70980394, 0.2784314 , 0.31764707],
#         [0.7254902 , 0.2901961 , 0.31764707]],
#
#        [[0.32156864, 0.08627451, 0.22352941],
#         [0.32156864, 0.08627451, 0.22352941],
#         [0.3764706 , 0.1254902 , 0.24313726],
#         ...,
#         [0.7019608 , 0.27450982, 0.30980393],
#         [0.70980394, 0.2784314 , 0.31764707],
#         [0.7254902 , 0.2901961 , 0.31764707]]], dtype=float32)

# %%
import numpy as np

# %%
img_new = np.zeros([100,100])

# %%
plt.imshow(img_new, cmap='gray')

# %%
img_new[34,57] = 0.5

# %%
plt.imshow(img_new)

# %%
img_new[34] =1

# %%
plt.imshow(img_new, cmap='gray')

# %%
img_new[34] =1
img_new[0,34] =1

# %%
plt.imshow(img_new, cmap='gray')

# %%
np.random.randint(12,78)
# Out:
# 32

# %%
img_new = np.zeros([100,100],dtype = np.uint8)

# %%
for i in range(100):
    for j in range(100):
        img_new[i,j] = np.random.randint(0,255)

# %%
plt.imshow(img_new, cmap= 'gray')

# %%
img_gray = cv2.imread('images/lenna.png',0)

# %%
img_gray.shape
# Out:
# (512, 512)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
img_plt.shape
# Out:
# (512, 512, 3)

# %%
r = img_plt[:,:,0]
g = img_plt[:,:,1]
b = img_plt[:,:,2]

# %%
r.shape, g.shape, b.shape
# Out:
# ((512, 512), (512, 512), (512, 512))

# %%
plt.subplot(1,3,1)
plt.imshow(r,cmap='gray')
plt.subplot(1,3,2)
plt.imshow(g,cmap='gray')
plt.subplot(1,3,3)
plt.imshow(b,cmap='gray')

# %%
plt.subplot(1,3,1)
plt.imshow(r,cmap='Rednew_img = (r =s')
plt.subplot(1,3,2)
plt.imshow(g,cmap='Greens')
plt.subplot(1,3,3)
plt.imshow(b,cmap='Blues')

# %%
new_img = (r +g +b)/3

# %%
plt.imshow(new_img, cmap = 'gray')

# %%
plt.subplot(1,2,1)
plt.title('Image Read using CV2')
plt.imshow(img1)
plt.subplot(1,2,2)
plt.title('Image Read using matlabplotlib')
plt.imshow(img_plt)

# %%
img2 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# %%
plt.subplot(1,2,1)
plt.title('Image Read using CV2')
plt.imshow(img2)
plt.subplot(1,2,2)
plt.title('Image Read using matlabplotlib')
plt.imshow(img_plt)

# %%
import sys

# %%
sys.getsizeof(img_plt)
# Out:
# 3145872

# %%
sys.getsizeof(img1)
# Out:
# 786576
